# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# #close world##Non-Defended

# %% [markdown]
# ****final graph of DNN Close world***reserch paper1

# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 21)  # Assuming 20 epochs
training_accuracy = [0.8159, 0.9350, 0.9498, 0.9584, 0.9645, 0.9691, 0.9722, 0.9741, 0.9758, 0.9776, 0.9790, 0.9810, 0.9814, 0.9819, 0.9835, 0.9836, 0.9854, 0.9853, 0.9861, 0.9866]
training_loss = [0.7400, 0.2541, 0.1887, 0.1558, 0.1313, 0.1147, 0.1004, 0.0937, 0.0870, 0.0816, 0.0766, 0.0692, 0.0668, 0.0655, 0.0606, 0.0585, 0.0541, 0.0524, 0.0520, 0.0492]
validation_accuracy = [0.9498, 0.9602, 0.9645, 0.9699, 0.9735, 0.9728, 0.9727, 0.9739, 0.9755, 0.9777, 0.9772, 0.9768, 0.9797, 0.9784, 0.9765, 0.9783, 0.9786, 0.9778, 0.9793, 0.9803]
validation_loss = [0.2037, 0.1629, 0.1443, 0.1285, 0.1131, 0.1214, 0.1207, 0.1111, 0.1118, 0.1014, 0.1069, 0.1034, 0.0941, 0.0986, 0.1082, 0.0993, 0.0973, 0.1104, 0.0987, 0.0979]

# Plotting
plt.figure(figsize=(10, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, 'b-', label='Training Accuracy', marker='o')
plt.plot(epochs, validation_accuracy, 'r--', label='Validation Accuracy', marker='s')

# Loss plot
plt.plot(epochs, training_loss, 'g-.', label='Training Loss', marker='^')
plt.plot(epochs, validation_loss, 'y:', label='Validation Loss', marker='*')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# //DF close world reserch paper 1

# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 41)  # 40 epochs
training_accuracy = [0.4904, 0.8287, 0.8966, 0.9224, 0.9383, 0.9476, 0.9553, 0.9607, 0.9648, 0.9689, 0.9711, 0.9731, 0.9755, 0.9774, 0.9787, 0.9797, 0.982, 0.9821, 0.9837, 0.9844, 0.9856, 0.9856, 0.9871, 0.987, 0.9873, 0.9877, 0.9882, 0.9892, 0.9886, 0.9893, 0.9901, 0.9906, 0.9908, 0.9906, 0.9904, 0.9907, 0.9914, 0.992, 0.9919, 0.9914]
validation_accuracy = [0.8057, 0.8934, 0.9551, 0.9583, 0.9676, 0.9683, 0.9724, 0.9708, 0.9765, 0.9748, 0.9794, 0.9785, 0.9779, 0.980, 0.9792, 0.9814, 0.9806, 0.9805, 0.9822, 0.9816, 0.9818, 0.982, 0.9826, 0.9826, 0.9834, 0.9828, 0.9825, 0.9821, 0.982, 0.9837, 0.9835, 0.9819, 0.982, 0.9826, 0.9844, 0.9831, 0.9834, 0.9828, 0.9826, 0.9842]

training_loss = [1.9718, 0.6830, 0.4246, 0.3142, 0.2482, 0.2121, 0.1810, 0.1561, 0.1416, 0.1258, 0.1137, 0.1054, 0.0968, 0.0886, 0.0808, 0.0782, 0.0714, 0.0683, 0.0631, 0.0595, 0.0565, 0.0553, 0.0505, 0.0502, 0.0493, 0.0491, 0.0458, 0.043, 0.0446, 0.0411, 0.0385, 0.0381, 0.037, 0.0377, 0.0364, 0.035, 0.0337, 0.0323, 0.0316, 0.0328]
validation_loss = [0.7771, 0.4083, 0.1897, 0.1721, 0.1341, 0.1263, 0.1137, 0.1160, 0.1005, 0.1041, 0.0861, 0.0919, 0.0865, 0.0859, 0.0889, 0.0784, 0.0821, 0.0883, 0.0821, 0.0768, 0.0788, 0.0782, 0.0763, 0.0762, 0.0779, 0.0778, 0.0751, 0.0793, 0.0838, 0.0719, 0.0744, 0.0757, 0.0755, 0.0786, 0.0736, 0.0764, 0.0732, 0.078, 0.0859, 0.0731]

# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, 'b-', label='Training Accuracy', marker='o')
plt.plot(epochs, validation_accuracy, 'r--', label='Validation Accuracy', marker='s')

# Loss plot
plt.plot(epochs, training_loss, 'g-.', label='Training Loss', marker='^')
plt.plot(epochs, validation_loss, 'y:', label='Validation Loss', marker='*')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# DNN open world for research paper 1

# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 21)  # Assuming 20 epochs
training_accuracy = [0.7810, 0.9071, 0.9289, 0.9390, 0.9482, 0.9539, 0.9580, 0.9623, 0.9649, 0.9685, 0.9701, 0.9712, 0.9733, 0.9745, 0.9767, 0.9760, 0.9776, 0.9782, 0.9794, 0.9809]
training_loss = [0.8543, 0.3440, 0.2597, 0.2163, 0.1852, 0.1625, 0.1477, 0.1323, 0.1206, 0.1095, 0.1037, 0.0994, 0.0923, 0.0878, 0.0812, 0.0817, 0.0772, 0.0744, 0.0700, 0.0694]
validation_accuracy = [0.9188, 0.9336, 0.9457, 0.9404, 0.9561, 0.9583, 0.9566, 0.9598, 0.9660, 0.9577, 0.9669, 0.9553, 0.9637, 0.9612, 0.9673, 0.9671, 0.9663, 0.9585, 0.9644, 0.9670]
validation_loss = [0.3075, 0.2420, 0.2030, 0.2187, 0.1678, 0.1586, 0.1676, 0.1544, 0.1441, 0.1637, 0.1357, 0.1787, 0.1535, 0.1595, 0.1389, 0.1461, 0.1418, 0.1659, 0.1435, 0.1458]

# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, color='purple', linestyle='-', marker='s', label='Training Accuracy')
plt.plot(epochs, validation_accuracy, color='red', linestyle='--', marker='^', label='Validation Accuracy')

# Loss plot
plt.plot(epochs, training_loss, color='green', linestyle='-.', marker='*', label='Training Loss')
plt.plot(epochs, validation_loss, color='orange', linestyle=':', marker='o', label='Validation Loss')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# TPR and FPR values
thresholds = [0.10874906186625455, 0.35328298736360164, 0.5307237540651162, 0.6594798177629646, 0.7529088772014396, 0.8207036582537898, 0.8698974783089168, 0.9055939123714077, 0.9314962595229367, 0.9502917388356261, 0.963930272846737, 0.9738267807717386, 0.9810079682094667, 0.9862188419243761, 0.99]
TPR = [0.9829473684210527, 0.9790526315789474, 0.9755789473684211, 0.9710526315789474, 0.9671578947368421, 0.9625263157894737, 0.9588421052631579, 0.9550526315789474, 0.9502105263157895, 0.9469473684210526, 0.9427368421052632, 0.9371578947368421, 0.9336842105263158, 0.9287368421052632, 0.9238947368421052]
FPR = [0.04225, 0.03985, 0.0338, 0.02715, 0.02205, 0.01865, 0.01585, 0.0134, 0.01135, 0.0096, 0.00865, 0.0075, 0.00655, 0.0057, 0.00475]

# Plotting
plt.figure(figsize=(6, 4))
plt.plot(FPR, TPR, marker='o', linestyle='-')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve for OpenWorld_Non_Defended')
plt.grid(True)
plt.show()

# %% [markdown]
# **RESEARCH PAPER 2**

# %% [markdown]
# For Defended Close world WTFPAD

# %%
import matplotlib.pyplot as plt

# Define data for training and validation
training_accuracy = [0.4257, 0.6486, 0.7180, 0.7583, 0.7865, 0.8099, 0.8248, 0.8389, 0.8516, 0.8603, 0.8703, 0.8785, 0.8853, 0.8901, 0.8961, 0.9011, 0.9040, 0.9089, 0.9126, 0.9164, 0.9190, 0.9212, 0.9240, 0.9272, 0.9287]
validation_accuracy = [0.4774, 0.7555, 0.7448, 0.8219, 0.8210, 0.8190, 0.8562, 0.8403, 0.8493, 0.8707, 0.8709, 0.8740, 0.8727, 0.8701, 0.8749, 0.8797, 0.8792, 0.8793, 0.8731, 0.8819, 0.8775, 0.8733, 0.8840, 0.8852, 0.8835]

validation_loss = [1.9232, 0.8902, 0.9089, 0.6391, 0.6496, 0.6550, 0.5266, 0.5830, 0.5611, 0.4850, 0.4873, 0.4661, 0.4915, 0.5147, 0.4880, 0.4913, 0.4916, 0.4720, 0.5105, 0.4803, 0.5306, 0.5323, 0.4899, 0.5001, 0.5078]

# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, color='purple', linestyle='-', marker='s', label='Training Accuracy')
plt.plot(epochs, validation_accuracy, color='red', linestyle='--', marker='^', label='Validation Accuracy')

# Loss plot
plt.plot(epochs, training_loss, color='green', linestyle='-.', marker='*', label='Training Loss')
plt.plot(epochs, validation_loss, color='orange', linestyle=':', marker='o', label='Validation Loss')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# for defended Open World Wtfpad

# %%
import matplotlib.pyplot as plt

epochs = range(1, 26)
training_accuracy = [34.58, 54.58, 63.44, 70.12, 75.34, 79.25, 82.15, 84.58, 86.21, 87.58, 88.76, 89.45, 90.12, 90.65, 91.02, 91.35, 91.65, 91.85, 92.03, 92.21, 92.35, 92.47, 92.58, 92.67, 92.76]
validation_accuracy = [34.51, 58.69, 70.98, 76.23, 80.12, 82.45, 84.12, 85.34, 86.45, 87.21, 88.12, 88.76, 89.23, 89.65, 90.01, 90.34, 90.56, 90.78, 90.96, 91.12, 91.25, 91.38, 91.49, 91.58, 91.67]
training_loss = [2.4371, 1.5788, 1.2625, 1.0422, 0.8993, 0.7865, 0.6912, 0.6115, 0.5467, 0.4932, 0.4489, 0.4123, 0.3812, 0.3544, 0.3310, 0.3102, 0.2911, 0.2743, 0.2594, 0.2462, 0.2344, 0.2239, 0.2145, 0.2059, 0.1982]
validation_loss = [2.5501, 1.5139, 1.0192, 0.7684, 0.6232, 0.5321, 0.4689, 0.4234, 0.3892, 0.3621, 0.3398, 0.3210, 0.3049, 0.2910, 0.2789, 0.2683, 0.2588, 0.2503, 0.2426, 0.2356, 0.2292, 0.2233, 0.2179, 0.2128, 0.2082]


# Plotting
plt.figure(figsize=(10, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, 'b-', label='Training Accuracy', marker='o')
plt.plot(epochs, validation_accuracy, 'r--', label='Validation Accuracy', marker='s')

# Loss plot
plt.plot(epochs, training_loss, 'g-.', label='Training Loss', marker='o')
plt.plot(epochs, validation_loss, 'm:', label='Validation Loss', marker='*')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Thresholds and corresponding precision and recall values
thresholds = [0.10874906186625455, 0.35328298736360164, 0.5307237540651162, 0.6594798177629646, 0.7529088772014396, 0.8207036582537898, 0.8698974783089168, 0.9055939123714077, 0.9314962595229367, 0.9502917388356261, 0.963930272846737, 0.9738267807717386, 0.9810079682094667, 0.9862188419243761, 0.99]
tpr = [0.9146315789473685, 0.7563157894736842, 0.5782105263157895, 0.46757894736842104, 0.38852631578947366, 0.3223157894736842, 0.27463157894736845, 0.23242105263157894, 0.19726315789473683, 0.16442105263157894, 0.1337894736842105, 0.10747368421052632, 0.08694736842105263, 0.06747368421052631, 0.05284210526315789]
fpr = [0.51295, 0.33995, 0.16845, 0.089, 0.0524, 0.0308, 0.0193, 0.01115, 0.00665, 0.0034, 0.0021, 0.00135, 0.00075, 0.00045, 0.0002]

# Custom x-axis ticks
x_ticks = [i / 10 for i in range(1, 11)]

# Plotting TPR and FPR against threshold
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precision, label='Precision', marker='o')
plt.plot(thresholds, recall, label='Recall', marker='o')
plt.title('Precision and Recall vs. Threshold')
plt.xlabel('Threshold')
plt.ylabel('Value')
plt.xticks(x_ticks)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Thresholds and corresponding TPR and FPR values
thresholds = [0.10874906186625455, 0.35328298736360164, 0.5307237540651162, 0.6594798177629646, 0.7529088772014396, 0.8207036582537898, 0.8698974783089168, 0.9055939123714077, 0.9314962595229367, 0.9502917388356261, 0.963930272846737, 0.9738267807717386, 0.9810079682094667, 0.9862188419243761, 0.99]
tpr = [0.9146315789473685, 0.7563157894736842, 0.5782105263157895, 0.46757894736842104, 0.38852631578947366, 0.3223157894736842, 0.27463157894736845, 0.23242105263157894, 0.19726315789473683, 0.16442105263157894, 0.1337894736842105, 0.10747368421052632, 0.08694736842105263, 0.06747368421052631, 0.05284210526315789]
fpr = [0.51295, 0.33995, 0.16845, 0.089, 0.0524, 0.0308, 0.0193, 0.01115, 0.00665, 0.0034, 0.0021, 0.00135, 0.00075, 0.00045, 0.0002]

# Custom x-axis ticks
x_ticks = [i / 10 for i in range(11)]

# Plotting TPR and FPR against threshold
plt.figure(figsize=(10, 6))
plt.plot(thresholds, tpr, label='True Positive Rate (TPR)', marker='*', color='blue', linestyle='-')
plt.plot(thresholds, fpr, label='False Positive Rate (FPR)', marker='o', color='red', linestyle='-')
plt.title('ROC curve between TPR and FPR vs. Threshold')
plt.xlabel('Threshold')
plt.ylabel('TPR-FPR Value')
plt.xticks(x_ticks)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# FOR DEFENDED OPEN WORLD WALKIE TALKIE

# %%
import matplotlib.pyplot as plt

# Test accuracies achieved by Model 1 on different folds
model1_test_accuracies = [96.83, 96.43, 96.93, 96.74, 96.81]

# Test accuracies achieved by Model 2 on different folds
model2_test_accuracies = [34.51, 58.69, 70.98, 74.58, 77.78]

# Folds
folds = [1, 2, 3, 4, 5]

plt.figure(figsize=(10, 6))

# Plotting test accuracies for Model 1
plt.bar([fold - 0.2 for fold in folds], model1_test_accuracies, width=0.4, label='Model 1')

# Plotting test accuracies for Model 2
plt.bar([fold + 0.2 for fold in folds], model2_test_accuracies, width=0.4, label='Model 2')

plt.xlabel('Fold')
plt.ylabel('Test Accuracy (%)')
plt.title('Comparison of Test Accuracies between Model 1 and Model 2')
plt.xticks(folds)
plt.legend()
plt.ylim(0, 100)
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt

# Test accuracies achieved by Model 1 on different folds
model1_test_accuracies = [96.83, 96.43, 96.93, 96.74, 96.81]

# Test accuracies achieved by Model 2 on different folds
model2_test_accuracies = [34.51, 58.69, 70.98, 74.58, 77.78]

# Folds
folds = [1, 2, 3, 4, 5]

plt.figure(figsize=(10, 6))

# Plotting test accuracies for Model 1
plt.bar([fold - 0.2 for fold in folds], model1_test_accuracies, width=0.4, label='Model 1')

# Plotting test accuracies for Model 2
plt.bar([fold + 0.2 for fold in folds], model2_test_accuracies, width=0.4, label='Model 2')

plt.xlabel('Fold')
plt.ylabel('Test Accuracy (%)')
plt.title('Comparison of Test Accuracies between Model 1 and Model 2')
plt.xticks(folds)
plt.legend()
plt.ylim(0, 100)
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt

# Model 1 accuracy values for each epoch
model1_epochs = list(range(1, 21))  # Model 1 has 20 epochs
model1_accuracy = training_accuracy = [0.7810, 0.9071, 0.9289, 0.9390, 0.9482, 0.9539, 0.9580, 0.9623, 0.9649, 0.9685, 0.9701, 0.9712, 0.9733, 0.9745, 0.9767, 0.9760, 0.9776, 0.9782, 0.9794, 0.9809]  # Example accuracy values for each epoch

# Model 2 accuracy values for each epoch
model2_epochs = list(range(1, 26))  # Model 2 has 25 epochs
model2_accuracy = [.3458, .5458, .6344, .7012, .7534, .7925, .8215, .8458, .8621, .8758, .8876, .8945, .9012, .9065, .9102, .9135, .9165, .9185, .9203, .9221, .9235, .9247, .9258, .9267, .9276]   # Example accuracy values for each epoch

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(model1_epochs, model1_accuracy, marker='o', linestyle='-', color='b', label='Accuracy_on_Non_defended_dataset')
plt.plot(model2_epochs, model2_accuracy, marker='o', linestyle='-', color='r', label='Accuracy_on_defended_dataset')

plt.title('Accuracy vs. Number of Epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.xticks(model1_epochs)  # Assuming both models have the same epochs
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy values for Model 1 and Model 2
model1_accuracy = [0.6, 0.7, 0.75, 0.8, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.0]  # Model 1 accuracy for 20 epochs
model2_accuracy = [0.5, 0.65, 0.7, 0.75, 0.8, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.88, 0.89, 0.9, 0.91, 0.92, 0.93, 0.94, 0.95, 0.96, 0.97, 0.98, 0.99, 1.0, 1.0]  # Model 2 accuracy for 25 epochs

# Number of epochs for Model 1 and Model 2
model1_epochs = list(range(1, len(model1_accuracy) + 1))
model2_epochs = list(range(1, len(model2_accuracy) + 1))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(model1_epochs, model1_accuracy, marker='o', linestyle='-', color='b', label='Model 1')
plt.plot(model2_epochs[:20], model2_accuracy[:20], marker='o', linestyle='-', color='r', label='Model 2')  # Considering only the first 20 epochs of Model 2

plt.title('Accuracy vs. Number of Epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.xticks(model1_epochs)  # Assuming both models have the same epochs
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Accuracy values for Model 1 and Model 2
Non_defended_Training_accuracy = [0.7810, 0.9071, 0.9289, 0.9390, 0.9482, 0.9539, 0.9580, 0.9623, 0.9649, 0.9685, 0.9701, 0.9712, 0.9733, 0.9745, 0.9767, 0.9760, 0.9776, 0.9782, 0.9794, 0.9809]  # Model 1 accuracy for 20 epochs
Defended_Training_accuracy = [.3458, .5458, .6344, .7012, .7534, .7925, .8215, .8458, .8621, .8758, .8876, .8945, .9012, .9065, .9102, .9135, .9165, .9185, .9203, .9221, .9235, .9247, .9258, .9267, .9276]  # Model 2 accuracy for 25 epochs

# Number of epochs for Model 1 and Model 2
Non_defended_Training_accuracy_epochs = list(range(1, len(model1_accuracy) + 1))
Defended_Training_accuracy_epochs = list(range(1, len(model2_accuracy) + 1))

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(Non_defended_Training_accuracy_epochs, Non_defended_Training_accuracy_epochs, marker='o', linestyle='-', color='b', label='Model 1')
plt.plot(Defended_Training_accuracy_epochs, Defended_Training_accuracy, marker='o', linestyle='-', color='r', label='Model 2')

plt.title('Accuracy vs. Number of Epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy')
plt.xticks(Non_defended_Training_accuracy_epochs)  # Assuming both models have the same epochs
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## DF close world research paper 2

# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 41)  # 40 epochs
training_accuracy = [0.4904, 0.8287, 0.8966, 0.9224, 0.9383, 0.9476, 0.9553, 0.9607, 0.9648, 0.9689, 0.9711, 0.9731, 0.9755, 0.9774, 0.9787, 0.9797, 0.982, 0.9821, 0.9837, 0.9844, 0.9856, 0.9856, 0.9871, 0.987, 0.9873, 0.9877, 0.9882, 0.9892, 0.9886, 0.9893, 0.9901, 0.9906, 0.9908, 0.9906, 0.9904, 0.9907, 0.9914, 0.992, 0.9919, 0.9914]
validation_accuracy = [0.8057, 0.8934, 0.9551, 0.9583, 0.9676, 0.9683, 0.9724, 0.9708, 0.9765, 0.9748, 0.9794, 0.9785, 0.9779, 0.980, 0.9792, 0.9814, 0.9806, 0.9805, 0.9822, 0.9816, 0.9818, 0.982, 0.9826, 0.9826, 0.9834, 0.9828, 0.9825, 0.9821, 0.982, 0.9837, 0.9835, 0.9819, 0.982, 0.9826, 0.9844, 0.9831, 0.9834, 0.9828, 0.9826, 0.9842]

training_loss = [1.9718, 0.6830, 0.4246, 0.3142, 0.2482, 0.2121, 0.1810, 0.1561, 0.1416, 0.1258, 0.1137, 0.1054, 0.0968, 0.0886, 0.0808, 0.0782, 0.0714, 0.0683, 0.0631, 0.0595, 0.0565, 0.0553, 0.0505, 0.0502, 0.0493, 0.0491, 0.0458, 0.043, 0.0446, 0.0411, 0.0385, 0.0381, 0.037, 0.0377, 0.0364, 0.035, 0.0337, 0.0323, 0.0316, 0.0328]
validation_loss = [0.7771, 0.4083, 0.1897, 0.1721, 0.1341, 0.1263, 0.1137, 0.1160, 0.1005, 0.1041, 0.0861, 0.0919, 0.0865, 0.0859, 0.0889, 0.0784, 0.0821, 0.0883, 0.0821, 0.0768, 0.0788, 0.0782, 0.0763, 0.0762, 0.0779, 0.0778, 0.0751, 0.0793, 0.0838, 0.0719, 0.0744, 0.0757, 0.0755, 0.0786, 0.0736, 0.0764, 0.0732, 0.078, 0.0859, 0.0731]

# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, color='purple', linestyle='-', marker='s', label='Training Accuracy')
plt.plot(epochs, validation_accuracy, color='orange', linestyle='--', marker='o', label='Validation Accuracy')

# Loss plot
plt.plot(epochs, training_loss, color='green', linestyle='-', marker='*', label='Training Loss')
plt.plot(epochs, validation_loss, color='blue', linestyle='--', marker='^', label='Validation Loss')

# Adding labels and legend
plt.xlabel('Epochs')
plt.ylabel('Accuracy/Loss')
plt.title('Training and Validation Metrics')
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
epochs = range(1, 21)  # Assuming 20 epochs
training_accuracy = [0.8159, 0.9350, 0.9498, 0.9584, 0.9645, 0.9691, 0.9722, 0.9741, 0.9758, 0.9776, 0.9790, 0.9810, 0.9814, 0.9819, 0.9835, 0.9836, 0.9854, 0.9853, 0.9861, 0.9866]
training_loss = [0.7400, 0.2541, 0.1887, 0.1558, 0.1313, 0.1147, 0.1004, 0.0937, 0.0870, 0.0816, 0.0766, 0.0692, 0.0668, 0.0655, 0.0606, 0.0585, 0.0541, 0.0524, 0.0520, 0.0492]
validation_accuracy = [0.9498, 0.9602, 0.9645, 0.9699, 0.9735, 0.9728, 0.9727, 0.9739, 0.9755, 0.9777, 0.9772, 0.9768, 0.9797, 0.9784, 0.9765, 0.9783, 0.9786, 0.9778, 0.9793, 0.9803]
validation_loss = [0.2037, 0.1629, 0.1443, 0.1285, 0.1131, 0.1214, 0.1207, 0.1111, 0.1118, 0.1014, 0.1069, 0.1034, 0.0941, 0.0986, 0.1082, 0.0993, 0.0973, 0.1104, 0.0987, 0.0979]

# Plotting
plt.figure(figsize=(10, 6))

# Accuracy plot
plt.plot(epochs, training_accuracy, color='navy', linestyle='-', marker='o', label='Training Accuracy')
plt.plot(epochs, validation_accuracy, color='orangered', linestyle='--', marker='s', label='Validation Accuracy')

# Loss plot
plt.plot(epochs, training_loss, color='darkgreen', linestyle='-.', marker='x', label='Training Loss')
plt.plot(epochs, validation_loss, color='goldenrod', linestyle=':', marker='d', label='Validation Loss')

plt.title('Training and Validation Metrics')
plt.xlabel('No. of Epochs')
plt.ylabel('Metrics')
plt.legend()

plt.grid(True)
plt.tight_layout()
plt.show()
